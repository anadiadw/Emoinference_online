# %%
import pandas as pd
import numpy as np
import os
from os import listdir
import glob
from glob import glob
from os.path import isfile, join
import shutil
import PIL
from PIL import Image
import random
import scipy as sp
from scipy import stats
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Emoinference Experiments

# %%
exp_pilot = pd.read_csv("C:/Users/ayesh/Desktop/Gradstuff/ppt_consents/Pavlovia_Consent_September 4, 2021_12.14.csv", header = 0)
exp_1 = pd.read_csv("C:/Users/ayesh/Desktop/Gradstuff/ppt_consents/Pavlovia_Consent - modified_September 4, 2021_12.34.csv", header = 0)
exp_xy = pd.read_csv("C:/Users/ayesh/Desktop/Gradstuff/ppt_consents/Pavlovia_Consent - XYversion_September 4, 2021_12.50.csv", header = 0)
exp_happy = pd.read_csv("C:/Users/ayesh/Desktop/Gradstuff/ppt_consents/Pavlovia_Consent - XYversion - happy_September 4, 2021_13.08.csv", header = 0)
exp_seq = pd.read_csv("C:/Users/ayesh/Desktop/Gradstuff/ppt_consents/Pavlovia_Consent - SEQ-XYversion_September 4, 2021_13.22.csv", header = 0)

# %%
analysis_path = '/Users/ayesh/Downloads/sequenced_emoinference_157547_2021-09-04_22h00.20_2dd86fd3-9bcc-46a1-b98a-0995da5ea1b7/'
analysis_files = [f for f in listdir(analysis_path) if isfile(join(analysis_path, f))]
all_fs = []
for f in analysis_files:
    all_fs.append(analysis_path + f)
dem_pt = []
empties = []
for pt_file in all_fs:
    df = pd.read_csv(pt_file)
    if df.empty == True:
        empties.append(pt_file)
    else:  
        df = pd.read_csv(pt_file, header=0)
        df.columns = df.columns.str.replace(".", "_")
        df.replace(r'\s+',np.nan,regex=True).replace('',np.nan)
        participant_name = df.workerID[0]
        dem_pt.append(participant_name)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-21-0a1cb87aa20b> in <module>
#       7 empties = []
#       8 for pt_file in all_fs:
# ----> 9     df = pd.read_csv(pt_file)
#      10     if df.empty == True:
#      11         empties.append(pt_file)
#
# ...

# %%
participant_name
# Out:
# 'A2FL477TMKC91L'

# %%
len(dem_pt)
# Out:
# 41

# %%
df
# Out:
#                                         male_neufacesB  \
# 0    ["m_neutral/17M_NE_C.jpg","m_neutral/10M_NE_C....
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 524                                                NaN
# 525                                                NaN
# 526                                                NaN
# 527                                                NaN
# 528                                                NaN
#
#                                         male_neufacesY  \
# 0    ["m_neutral/06M_NE_C.jpg","m_neutral/09M_NE_C....
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# ...
