# %%
import pandas as pd
import numpy as np
import os
from os import listdir
import glob
from glob import glob
from os.path import isfile, join
import shutil
import PIL
from PIL import Image
import random
import scipy as sp
from scipy import stats
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#df_folder = '/Users/ayesh/Downloads/test3/complete_data/usable/' ##orig threshold AB3 66% and AC 33%
#df_folder = '/Users/ayesh/Downloads/exp2/complete_data/usable/' ##Ali's threshold AB3 at 75%; no AC exclusion
df_folder = '/Users/ayesh/Downloads/Emoinference_dt/XY_exp2/complete_data/' ##no exclusion
#path = '/Users/ayesh/Desktop/Fearmap_data/rotation_project/data/'
 
behav_files = [f for f in listdir(df_folder) if isfile(join(df_folder, f))]

csv_list = []
all_good = []
not_usable = []

for b in behav_files:
    if b[-4:] == ".csv":
        csv_list.append(df_folder + b)
        
for a in csv_list:
    try:
        one_file = pd.read_csv(a, header = 0)
        one_file.columns = one_file.columns.str.replace(".", "_")
        fin_q = 'key_resp_33_keys'
        #subid = 'workerID'
        if fin_q in one_file.columns:
            all_good.append(a)
        else:
            not_usable.append(one_file.workerID[0])
    except Exception as e:
        print(e)

# %%
print("notusable =" , not_usable)

#print(all_good)
# Out:
# notusable = []

# %%
subid = []
avg_AB1 = []
avg_AB2 = []
avg_AB3 = []
avg_BC = []
avg_XY = []
avg_AC = []


for pt_file in all_good:
    df = pd.read_csv(pt_file, header=0)
    df.columns = df.columns.str.replace(".", "_")
    df.replace(r'\s+',np.nan,regex=True).replace('',np.nan)
    participant_name = df.workerID[0]
    AB1corr = df.key_resp_corr
    AB2corr = df.key_resp_2_corr
    AB3corr = df.key_resp_3_corr
    BCXYcorr = df.key_resp_4_corr
    ACcorr = df.key_resp_5_corr
   
    #allgood_check = df.key_resp_33_keys[480]

    AB1_trialresp = df.key_resp_keys
    AB2_trialresp = df.key_resp_2_keys
    AB3_trialresp = df.key_resp_3_keys
    BCXY_trialresp = df.key_resp_4_keys
    AC_trialresp = df.key_resp_5_keys
    
    AB1_trialresp_rt = df.key_resp_rt
    AB2_trialresp_rt = df.key_resp_2_rt
    AB3_trialresp_rt = df.key_resp_3_rt
    BCXY_trialresp_rt = df.key_resp_4_rt
    AC_trialresp_rt = df.key_resp_5_rt
    overlap = df.test_overlap
    
    t_AB1trials = []
    t_AB2trials = []
    t_AB3trials = []
    t_BCtrials = []
    t_XYtrials = []
    t_ACtrials = []
    
    t_AB1corr = []
    t_AB2corr = []
    t_AB3corr = []
    t_BCcorr = []
    t_XYcorr = []
    t_ACcorr = []
    
    for index, row in df.iterrows():
        try:
            
            if np.isnan(AB1_trialresp[index]) == False:
                t_AB1trials.append(AB1_trialresp_rt[index])
            total_AB1resp = len(t_AB1trials)/48

            if AB1corr[index] == 1:
                t_AB1corr.append(AB1_trialresp_rt[index])
            prop_correct = len(t_AB1corr)/len(t_AB1trials)
            #prop_correct = len(t_AB1corr)/48


            if np.isnan(AB2_trialresp[index]) == False:
                t_AB2trials.append(AB2_trialresp_rt[index])
            total_AB2resp = len(t_AB2trials)/48

            if AB2corr[index] == 1:
                t_AB2corr.append(AB2_trialresp_rt[index])
            prop_correct2 = len(t_AB2corr)/len(t_AB2trials)
            #prop_correct2 = len(t_AB2corr)/48


            if np.isnan(AB3_trialresp[index]) == False:
                t_AB3trials.append(AB3_trialresp_rt[index])
            total_AB3resp = len(t_AB3trials)/48

            if AB3corr[index] == 1:
                t_AB3corr.append(AB3_trialresp_rt[index])
            prop_correct3 = len(t_AB3corr)/len(t_AB3trials)
            #prop_correct3 = len(t_AB3corr)/48


            if np.isnan(BCXY_trialresp[index]) == False and overlap[index] == 'BC':
                t_BCtrials.append(BCXY_trialresp_rt[index])
            total_BCresp = len(t_BCtrials)/48

            if BCXYcorr[index] == 1 and overlap[index] == 'BC':
                t_BCcorr.append(BCXY_trialresp_rt[index])
            prop_correctBC = len(t_BCcorr)/len(t_BCtrials)
            #prop_correctBC = len(t_BCcorr)/48

            if np.isnan(BCXY_trialresp[index]) == False and overlap[index] == 'XY':
                t_XYtrials.append(BCXY_trialresp_rt[index])
            total_XYresp = len(t_XYtrials)/48

            if BCXYcorr[index] == 1 and overlap[index] == 'XY':
                t_XYcorr.append(BCXY_trialresp_rt[index])
            prop_correctXY = len(t_XYcorr)/len(t_XYtrials)

            if np.isnan(AC_trialresp[index]) == False:
                t_ACtrials.append(AC_trialresp_rt[index])
            total_ACresp = len(t_ACtrials)/48

            if ACcorr[index] == 1:
                t_ACcorr.append(AC_trialresp_rt[index])
            prop_correctAC = len(t_ACcorr)/len(t_ACtrials)
            #prop_correctAC = len(t_ACcorr)/48

            
        except:
            pass
        
    subid.append(participant_name)
    avg_AB1.append(prop_correct)
    avg_AB2.append(prop_correct2)
    avg_AB3.append(prop_correct3)
    avg_BC.append(prop_correctBC)
    avg_XY.append(prop_correctXY)
    avg_AC.append(prop_correctAC)

# %%
df.workerID
# Out:
# 0      A1B5SSGMTAQ9B5
# 1      A1B5SSGMTAQ9B5
# 2      A1B5SSGMTAQ9B5
# 3      A1B5SSGMTAQ9B5
# 4      A1B5SSGMTAQ9B5
#             ...
# 524    A1B5SSGMTAQ9B5
# 525    A1B5SSGMTAQ9B5
# 526    A1B5SSGMTAQ9B5
# 527    A1B5SSGMTAQ9B5
# 528    A1B5SSGMTAQ9B5
# Name: workerID, Length: 529, dtype: object

# %%
plt.plot(avg_AC)

# %%
my_df = pd.DataFrame(list(zip(subid, avg_AB1, avg_AB2, avg_AB3, avg_BC, avg_XY, avg_AC)), 
                     columns = ['participant', 'Avg AB1', 'Avg AB2', 'Avg AB3', 'Avg BC', 'Avg XY', 'Avg AC'])

my_df
# Out:
#        participant   Avg AB1   Avg AB2   Avg AB3    Avg BC    Avg XY    Avg AC
# 0   A106MX66IVHW6T  0.562500  0.702128  0.770833  0.595745  0.422222  0.531915
# 1   A12FTSX85NQ8N9  0.636364  0.957447  0.979167  0.729167  0.702128  0.765957
# 2   A140BPA53B1ZN2  0.310345  0.409091  0.307692  0.235294  0.322581  0.333333
# 3   A173A97OFDAX9F  0.340426  0.750000  0.854167  0.354167  0.437500  0.520833
# 4   A1DZMZTXWOM9MR  0.354167  0.854167  0.916667  0.625000  0.625000  0.458333
# 5   A1Q56N80RJLQ7S  0.558140  0.500000  0.652174  0.129032  0.500000  0.261905
# 6   A1SISJL5ST2PWH  0.375000  0.479167  0.750000  0.312500  0.229167  0.375000
# 7   A1SOFLJOEQB591  0.645833  0.854167  0.875000  0.479167  0.489362  0.312500
# 8   A1T7EB1WEDCMXV  0.687500  0.937500  0.937500  0.645833  0.787234  0.791667
# 9   A1USR9JCAMDGM3  0.765957  0.872340  0.958333  0.770833  0.804348  0.893617
# 10  A1V1JNPU0KOA3X  0.583333  0.833333  0.875000  0.510638  0.479167  0.574468
# 11  A23EGLIF8IEH11  0.488889  0.826087  0.895833  0.645833  0.708333  0.770833
# 12  A2615YW1YERQBO  0.638298  0.791667  0.916667  0.687500  0.574468  0.717391
# 13  A2ASTDMWBCFIP0  0.638298  0.937500  1.000000  0.958333  0.854167  0.875000
# 14  A2BK9RMC0NOIH8  0.458333  0.744681  0.854167  0.437500  0.479167  0.375000
# 15  A2FECFFPL93VAI  0.361111  0.377778  0.500000  0.200000  0.375000  0.260870
# 16  A2I9R6P8PE5FDL  0.437500  0.666667  0.729167  0.583333  0.520833  0.458333
# 17  A2J236790OL3F3  0.687500  0.916667  0.958333  0.791667  0.750000  0.916667
# 18  A2N2GFB33ZMYGF  0.500000  0.812500  0.875000  0.520833  0.479167  0.520833
# 19  A2NEFRREWF33YP  0.395833  0.708333  0.937500  0.375000  0.500000  0.395833
# 20  A2PSR3CMNR1R9X  0.847826  0.958333  0.979167  0.791667  0.708333  0.700000
# 21  A2SWQM5X54P1O5  0.428571  0.680851  0.645833  0.575758  0.548387  0.326087
# 22  A2V27A9GZA1NR2  0.844444  0.872340  0.934783  0.723404  0.695652  0.638298
# 23  A2WBGRTWOXDE6M  0.651163  0.958333  1.000000  0.790698  0.780488  0.791667
# 24  A36QBKROJ4J9EJ  0.666667  0.916667  0.979167  0.708333  0.750000  0.812500
# 25  A36UFZOEMNO9GJ  0.541667  0.680851  0.765957  0.562500  0.479167  0.541667
# 26  A39LVL4A92K88X  0.553191  0.673913  0.787234  0.484848  0.451613  0.304348
# 27  A3BO3HMV0F7Q5H  0.512195  0.604167  0.770833  0.513514  0.410256  0.340909
# 28  A3BUWQ5C39GRQC  0.541667  0.666667  0.750000  0.458333  0.425532  0.475000
# 29  A3CTXNQ2GXIQSP  0.791667  0.979167  0.958333  0.750000  0.687500  0.833333
# 30  A3I8W5848LIHPC  0.571429  0.178571  0.166667  0.384615  0.562500  0.260870
# 31  A3N8N0APBBUPT3  0.400000  0.375000  0.227273  0.341463  0.333333  0.372093
# 32  A3NXT3OVGL7QNR  0.791667  0.895833  0.979167  0.812500  0.829787  0.875000
# 33  A3UI9A8F9IDZTG  0.297872  0.465116  0.729167  0.458333  0.377778  0.510638
# 34   A46IWW0R7ADY2  0.404762  0.510638  0.238095  0.318182  0.347826  0.333333
# 35   A8UJNIY9R8S7W  0.400000  0.645833  0.704545  0.520833  0.479167  0.479167
# 36   AFKB7F09OVKV7  0.583333  0.520833  0.680851  0.562500  0.382979  0.333333
# 37   APGX2WZ59OWDN  0.891304  0.958333  1.000000  0.957447  0.956522  1.000000
# 38   AQ5KOKZQSZU0B  0.750000  0.958333  0.979167  0.791667  0.750000  0.916667
# 39   AXKTYKCT9NGHS  0.791667  0.916667  1.000000  0.770833  0.638298  0.770833
# 40  A1LSSHKTJHSPWL  0.347826  0.489362  0.434783  0.380952  0.341463  0.382979
# 41  A368U10UFMP2J6  0.317073  0.318182  0.413043  0.368421  0.378378  0.279070
# 42  A3QTA32K0LP9AE  0.600000  0.000000  0.500000  0.500000  0.142857  0.352941
# 43  A3EUTK958GXP5Z  0.288889  0.307692  0.350000  0.295455  0.232558  0.319149
# 44  A11TPUPFP2S4MK  0.479167  0.723404  0.893617  0.434783  0.404255  0.595745
# 45  A3PR7FCPPZ88JR  0.333333  0.388889  0.444444  0.380952  0.375000  0.350000
# 46  A2VE2JM0RFYIOU  0.361111  0.538462  0.477273  0.354839  0.285714  0.351351
# 47   AB3Z97M4JJLK5  0.216216  0.520000  0.333333  0.285714  0.250000  0.162791
# 48  A2FGKKWP33DFWS  0.488889  0.574468  0.844444  0.543478  0.282609  0.456522
# 49   AI0TZEH5DNODH  0.512195  0.352941  0.384615  0.421053  0.470588  0.351351
# 50   AVBRJBJONL47I  0.297872  0.531915  0.645833  0.404255  0.340426  0.638298
# 51  A1B5SSGMTAQ9B5  0.324324  0.290323  0.250000  0.250000  0.235294  0.450000

# %%
my_df.to_csv(r'/Users/ayesh/Desktop/Gradstuff/contingentproject/mem-gen_study/XY_mTurk_pavlovia_data/summaryXYdata/overall_inference.csv', index = False, header = True)

# %%
melted_df = pd.melt(my_df, id_vars=['participant'], value_vars=['Avg AB1', 'Avg AB2', 'Avg AB3', 'Avg BC', 'Avg XY', 'Avg AC'], var_name='condition', value_name='Total_acc')
melted_df
# Out:
#         participant condition  Total_acc
# 0    A106MX66IVHW6T   Avg AB1   0.562500
# 1    A12FTSX85NQ8N9   Avg AB1   0.636364
# 2    A140BPA53B1ZN2   Avg AB1   0.310345
# 3    A173A97OFDAX9F   Avg AB1   0.340426
# 4    A1DZMZTXWOM9MR   Avg AB1   0.354167
# ..              ...       ...        ...
# 307   AB3Z97M4JJLK5    Avg AC   0.162791
# 308  A2FGKKWP33DFWS    Avg AC   0.456522
# 309   AI0TZEH5DNODH    Avg AC   0.351351
# 310   AVBRJBJONL47I    Avg AC   0.638298
# 311  A1B5SSGMTAQ9B5    Avg AC   0.450000
#
# [312 rows x 3 columns]

# %% [markdown]
# ## check if meeting threshold 75% accuracy in AB3

# %%
below_threshAB = []
below_threshBC = []
below_threshXY = []
yikes = []
for index, rows in melted_df.iterrows():
    if melted_df.condition[index] == 'Avg AB3' and melted_df.Total_acc[index] <= 0.75: # previously 0.66:
        subb = [melted_df.Total_acc[index], melted_df.participant[index]]
        below_threshAB.append(subb)
    if melted_df.condition[index] == 'Avg BC' and melted_df.Total_acc[index] <= 0.33:
        below_threshBC.append(melted_df.participant[index])
    if melted_df.condition[index] == 'Avg XY' and melted_df.Total_acc[index] <= 0.33:
        below_threshXY.append(melted_df.participant[index])
    if melted_df.condition[index] == 'Avg AC' and melted_df.Total_acc[index] <= 0.33:
        subb = [melted_df.Total_acc[index], melted_df.participant[index]]
        yikes.append(subb)
print('AB', below_threshAB)
print('BC', below_threshBC)
print('XY', below_threshXY)
print('AC', yikes)
# Out:
# AB [[0.3076923076923077, 'A140BPA53B1ZN2'], [0.6521739130434783, 'A1Q56N80RJLQ7S'], [0.75, 'A1SISJL5ST2PWH'], [0.5, 'A2FECFFPL93VAI'], [0.7291666666666666, 'A2I9R6P8PE5FDL'], [0.6458333333333334, 'A2SWQM5X54P1O5'], [0.75, 'A3BUWQ5C39GRQC'], [0.16666666666666666, 'A3I8W5848LIHPC'], [0.22727272727272727, 'A3N8N0APBBUPT3'], [0.7291666666666666, 'A3UI9A8F9IDZTG'], [0.23809523809523808, 'A46IWW0R7ADY2'], [0.7045454545454546, 'A8UJNIY9R8S7W'], [0.6808510638297872, 'AFKB7F09OVKV7'], [0.43478260869565216, 'A1LSSHKTJHSPWL'], [0.41304347826086957, 'A368U10UFMP2J6'], [0.5, 'A3QTA32K0LP9AE'], [0.35, 'A3EUTK958GXP5Z'], [0.4444444444444444, 'A3PR7FCPPZ88JR'], [0.4772727272727273, 'A2VE2JM0RFYIOU'], [0.3333333333333333, 'AB3Z97M4JJLK5'], [0.38461538461538464, 'AI0TZEH5DNODH'], [0.6458333333333334, 'AVBRJBJONL47I'], [0.25, 'A1B5SSGMTAQ9B5']]
# BC ['A140BPA53B1ZN2', 'A1Q56N80RJLQ7S', 'A1SISJL5ST2PWH', 'A2FECFFPL93VAI', 'A46IWW0R7ADY2', 'A3EUTK958GXP5Z', 'AB3Z97M4JJLK5', 'A1B5SSGMTAQ9B5']
# XY ['A140BPA53B1ZN2', 'A1SISJL5ST2PWH', 'A3QTA32K0LP9AE', 'A3EUTK958GXP5Z', 'A2VE2JM0RFYIOU', 'AB3Z97M4JJLK5', 'A2FGKKWP33DFWS', 'A1B5SSGMTAQ9B5']
# AC [[0.2619047619047619, 'A1Q56N80RJLQ7S'], [0.3125, 'A1SOFLJOEQB591'], [0.2608695652173913, 'A2FECFFPL93VAI'], [0.32608695652173914, 'A2SWQM5X54P1O5'], [0.30434782608695654, 'A39LVL4A92K88X'], [0.2608695652173913, 'A3I8W5848LIHPC'], [0.27906976744186046, 'A368U10UFMP2J6'], [0.3191489361702128, 'A3EUTK958GXP5Z'], [0.16279069767441862, 'AB3Z97M4JJLK5']]

# %%
AB1_mean = np.mean(avg_AB1)
AB2_mean = np.mean(avg_AB2)
AB3_mean = np.mean(avg_AB3)
BC_mean = np.mean(avg_BC)
XY_mean = np.mean(avg_XY)
AC_mean = np.mean(avg_AC)

AB1_std = np.std(avg_AB1)
AB2_std = np.std(avg_AB2)
AB3_std = np.std(avg_AB3)
BC_std = np.std(avg_BC)
XY_std = np.std(avg_XY)
AC_std = np.std(avg_AC)


# Define labels, positions, bar heights and error bar heights
labels = ['AB1', 'AB2', 'AB3', 'BC', 'XY', 'AC']
x_pos = np.arange(len(labels))
CTEs = [AB1_mean, AB2_mean, AB3_mean, BC_mean, XY_mean, AC_mean]
error = [AB1_std, AB2_std, AB3_std, BC_std, XY_std, AC_std]

# Build the plot
fig, ax = plt.subplots(figsize=(10,8))
sns.swarmplot(data=melted_df, y = 'Total_acc', x = 'condition', palette = 'flare', ax = ax)

ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.8,
       width=0.4,
       color='lightblue',
       ecolor='black',
       capsize=10)
ax.set_ylabel('Proportion Accurate', fontsize = 'xx-large')
ax.set_xlabel('Test', fontsize = 2)
ax.set_xticks(x_pos)
ax.set_xticklabels(labels, fontsize = 'xx-large')
ax.set_title('Proportion correct in each test phase', fontsize = 'xx-large')

# ### swarmplot
red = '#c04e01'
blue = '#0165fc'

# %% [markdown]
# # JUNK _________________________________

# %%
#df = print(df.replace(r'^\s*$', np.nan, regex=True))

subid = []
avg_AB1_neu = []
avg_AB2_neu = []
avg_AB3_neu = []
avg_BC_neu = []
avg_XY_neu = []
avg_AC_neu = []


avg_AB1_emo = []
avg_AB2_emo = []
avg_AB3_emo = []
avg_BC_emo = []
avg_XY_emo = []
avg_AC_emo = []


for pt_file in all_good:
    df = pd.read_csv(pt_file, header=0)
    df.columns = df.columns.str.replace(".", "_")
    participant_name = df.workerID[0]
    AB1corr = df.key_resp_corr
    AB2corr = df.key_resp_2_corr
    AB3corr = df.key_resp_3_corr
    BCXYcorr = df.key_resp_4_corr
    ACcorr = df.key_resp_5_corr
    

    AB1_trialresp = df.key_resp_keys
    AB2_trialresp = df.key_resp_2_keys
    AB3_trialresp = df.key_resp_3_keys
    BCXY_trialresp = df.key_resp_4_keys
    AC_trialresp = df.key_resp_5_keys
 
    
    AB1_trialresp_rt = df.key_resp_rt
    AB2_trialresp_rt = df.key_resp_2_rt
    AB3_trialresp_rt = df.key_resp_3_rt
    BCXY_trialresp_rt = df.key_resp_4_rt
    AC_trialresp_rt = df.key_resp_5_rt

    
    AB1_trialtype = df.test1_face_image
    AB2_trialtype = df.test2_face_image
    AB3_trialtype = df.test3_face_image
    BCXY_trialtype = df.testBC_face_image
    ACobjectcue = df.testAC_objectC_image

    overlap = df.test_overlap
    ACobjectA = df.orig_objectA_image
    ACobjectC = df.objectC_image4
    overlapB_faceimage = df.face_image4
    overlap_list = []
    emo_faced = []
    neu_faced = []
    test = []
    
    t_AB1trials = []
    t_AB2trials = []
    t_AB3trials = []
    t_BCtrials = []
    t_XYtrials = []
    t_ACtrials = []
    
    fear_AB1trials = []
    fear_AB2trials = []
    fear_AB3trials = []
    fear_BCtrials = []
    fear_XYtrials = []
    fear_ACtrials = []
    
    neut_AB1trials = []
    neut_AB2trials = []
    neut_AB3trials = []
    neut_BCtrials = []
    neut_XYtrials = []
    neut_ACtrials = []
    
    f_AB1corr = []
    f_AB2corr = []
    f_AB3corr = []
    f_BCcorr = []
    f_XYcorr = []
    f_ACcorr = []
  
    
    n_AB1corr = []
    n_AB2corr = []
    n_AB3corr = []
    n_BCcorr = []
    n_XYcorr = []
    n_ACcorr = []
    
    
    for index, row in df.iterrows():
        if pd.isnull(ACobjectC[index]) == False:
            overlap_valence = overlapB_faceimage[index]
            if overlap_valence[2:6] == 'fear':
                emo_faced.append(ACobjectC[index])
            if overlap_valence[2:6] == 'neut':
                neu_faced.append(ACobjectC[index]) 
    
    for index, row in df.iterrows():         
        if ACobjectcue[index] in emo_faced:
            fear_ACtrials.append(ACobjectcue[index])
            if ACcorr[index] == 1:
                f_ACcorr.append(AC_trialresp_rt[index])
                
        if ACobjectcue[index] in neu_faced:
            neut_ACtrials.append(ACobjectcue[index])
            if ACcorr[index] == 1:
                n_ACcorr.append(AC_trialresp_rt[index]) 
    try:   
        prop_correctAC_emo = len(f_ACcorr)/len(fear_ACtrials)
        prop_correctAC_neut = len(n_ACcorr)/len(neut_ACtrials)
    except:
        pass
            
    for index, row in df.iterrows():
        valence1 = AB1_trialtype[index]
        valence2 = AB2_trialtype[index]
        valence3 = AB3_trialtype[index]
        valenceBC = BCXY_trialtype[index]
      
        
        if np.isnan(AB1_trialresp[index]) == False:
            #valence1 = AB1_trialtype[index]
            if valence1[2:6] == 'fear':
                fear_AB1trials.append(AB1_trialresp_rt[index])
                if AB1corr[index] == 1:
                    f_AB1corr.append(AB1_trialresp_rt[index])
            if valence1[2:6] == 'neut':
                neut_AB1trials.append(AB1_trialresp_rt[index])
                if AB1corr[index] == 1:
                    n_AB1corr.append(AB1_trialresp_rt[index])

        #prop_correct_emo = len(f_AB1corr)/len(fear_AB1trials)
        #prop_correct_neut = len(n_AB1corr)/len(neut_AB1trials)

        ##################################################################

        if np.isnan(AB2_trialresp[index]) == False:
            if valence2[2:6] == 'fear':
                fear_AB2trials.append(AB2_trialresp_rt[index])
                if AB2corr[index] == 1:
                    f_AB2corr.append(AB2_trialresp_rt[index])
            if valence2[2:6] == 'neut':
                neut_AB2trials.append(AB2_trialresp_rt[index])
                if AB2corr[index] == 1:
                    n_AB2corr.append(AB2_trialresp_rt[index])

       #################################################################

        if np.isnan(AB3_trialresp[index]) == False:
            if valence3[2:6] == 'fear':
                fear_AB3trials.append(AB3_trialresp_rt[index])
                if AB3corr[index] == 1:
                    f_AB3corr.append(AB3_trialresp_rt[index])
            elif valence3[2:6] == 'neut':
                neut_AB3trials.append(AB3_trialresp_rt[index])
                if AB3corr[index] == 1:
                    n_AB3corr.append(AB3_trialresp_rt[index])

        ######################################################################

        if np.isnan(BCXY_trialresp[index]) == False and overlap[index] == 'BC':
            if valenceBC[2:6] == 'fear':
                fear_BCtrials.append(BCXY_trialresp_rt[index])
                if BCXYcorr[index] == 1:
                    f_BCcorr.append(BCXY_trialresp_rt[index])
            elif valenceBC[2:6] == 'neut':
                neut_BCtrials.append(BCXY_trialresp_rt[index])
                if BCXYcorr[index] == 1:
                    n_BCcorr.append(BCXY_trialresp_rt[index])

        #############################################################
        
        if np.isnan(BCXY_trialresp[index]) == False and overlap[index] == 'XY':
            if valenceBC[2:6] == 'fear':
                fear_XYtrials.append(BCXY_trialresp_rt[index])
                if BCXYcorr[index] == 1:
                    f_XYcorr.append(BCXY_trialresp_rt[index])
            elif valenceBC[2:6] == 'neut':
                neut_XYtrials.append(BCXY_trialresp_rt[index])
                if BCXYcorr[index] == 1:
                    n_XYcorr.append(BCXY_trialresp_rt[index])

        #############################################################

                    
    try:
        prop_correct_emo = len(f_AB1corr)/len(fear_AB1trials)
        prop_correct_neut = len(n_AB1corr)/len(neut_AB1trials)
        prop_correct2_emo = len(f_AB2corr)/len(fear_AB2trials)
        prop_correct2_neut = len(n_AB2corr)/len(neut_AB2trials)
        prop_correct3_emo = len(f_AB3corr)/len(fear_AB3trials)
        prop_correct3_neut = len(n_AB3corr)/len(neut_AB3trials)
        prop_correctBC_emo = len(f_BCcorr)/len(fear_BCtrials)
        prop_correctBC_neut = len(n_BCcorr)/len(neut_BCtrials)
        prop_correctXY_emo = len(f_XYcorr)/len(fear_XYtrials)
        prop_correctXY_neut = len(n_XYcorr)/len(neut_XYtrials)

    except:
            pass
       
    ##############################################################################
    ## THE AC TEST!! 

    subid.append(participant_name)

    avg_AB1_neu.append(prop_correct_neut)
    avg_AB2_neu.append(prop_correct2_neut)
    avg_AB3_neu.append(prop_correct3_neut)
    avg_BC_neu.append(prop_correctBC_neut)
    avg_XY_neu.append(prop_correctXY_neut)
    avg_AC_neu.append(prop_correctAC_neut)


    avg_AB1_emo.append(prop_correct_emo)
    avg_AB2_emo.append(prop_correct2_emo)
    avg_AB3_emo.append(prop_correct3_emo)
    avg_BC_emo.append(prop_correctBC_emo)
    avg_XY_emo.append(prop_correctXY_emo)
    avg_AC_emo.append(prop_correctAC_emo)

# %%
val_df = pd.DataFrame(list(zip(subid, avg_AB1_neu, avg_AB2_neu, avg_AB3_neu, avg_BC_neu, avg_XY_neu, avg_AC_neu, avg_AB1_emo, avg_AB2_emo, avg_AB3_emo, avg_BC_emo, avg_XY_emo, avg_AC_emo)), 
                     columns = ['participant', 'Avg AB1', 'Avg AB2', 'Avg AB3', 'Avg BC', 'Avg XY', 'Avg AC', 'Avg AB1_emo', 'Avg AB2_emo', 'Avg AB3_emo', 'Avg BC_emo', 'Avg XY_emo', 'Avg AC_emo'])

val_df.to_csv(r'/Users/ayesh/Desktop/Gradstuff/contingentproject/mem-gen_study/XY_mTurk_pavlovia_data/summaryXYdata/overall_inference_valence.csv', index = False, header = True)

val_df
# Out:
#        participant   Avg AB1   Avg AB2   Avg AB3    Avg BC    Avg XY  \
# 0   A106MX66IVHW6T  0.666667  0.875000  0.916667  0.666667  0.458333
# 1   A12FTSX85NQ8N9  0.650000  1.000000  1.000000  0.750000  0.750000
# 2   A140BPA53B1ZN2  0.285714  0.454545  0.181818  0.250000  0.533333
# 3   A173A97OFDAX9F  0.478261  0.875000  0.791667  0.333333  0.541667
# 4   A1DZMZTXWOM9MR  0.416667  0.875000  0.875000  0.708333  0.666667
# 5   A1Q56N80RJLQ7S  0.700000  0.652174  0.708333  0.111111  0.625000
# 6   A1SISJL5ST2PWH  0.333333  0.458333  0.625000  0.333333  0.250000
# 7   A1SOFLJOEQB591  0.666667  0.833333  0.958333  0.750000  0.541667
# 8   A1T7EB1WEDCMXV  0.708333  0.958333  0.916667  0.750000  0.750000
# 9   A1USR9JCAMDGM3  0.791667  0.913043  0.916667  0.750000  0.958333
# 10  A1V1JNPU0KOA3X  0.750000  0.916667  0.958333  0.583333  0.541667
# 11  A23EGLIF8IEH11  0.454545  0.826087  0.916667  0.625000  0.916667
# 12  A2615YW1YERQBO  0.782609  0.791667  0.916667  0.666667  0.791667
# 13  A2ASTDMWBCFIP0  0.833333  0.958333  1.000000  1.000000  0.958333
# 14  A2BK9RMC0NOIH8  0.416667  0.695652  0.791667  0.500000  0.541667
# 15  A2FECFFPL93VAI  0.444444  0.454545  0.470588  0.111111  0.333333
# 16  A2I9R6P8PE5FDL  0.458333  0.708333  0.750000  0.541667  0.416667
# 17  A2J236790OL3F3  0.708333  0.958333  0.958333  0.666667  0.833333
# 18  A2N2GFB33ZMYGF  0.541667  0.916667  0.916667  0.541667  0.458333
# 19  A2NEFRREWF33YP  0.375000  0.750000  0.916667  0.416667  0.416667
# 20  A2PSR3CMNR1R9X  0.913043  1.000000  1.000000  0.833333  0.666667
# 21  A2SWQM5X54P1O5  0.600000  0.833333  0.750000  0.733333  0.529412
# 22  A2V27A9GZA1NR2  0.909091  0.958333  0.956522  0.583333  0.708333
# 23  A2WBGRTWOXDE6M  0.608696  1.000000  1.000000  0.695652  0.818182
# 24  A36QBKROJ4J9EJ  0.772727  0.958333  1.000000  0.750000  0.833333
# 25  A36UFZOEMNO9GJ  0.458333  0.739130  0.869565  0.583333  0.375000
# 26  A39LVL4A92K88X  0.500000  0.625000  0.913043  0.375000  0.437500
# 27  A3BO3HMV0F7Q5H  0.526316  0.625000  0.916667  0.647059  0.400000
# 28  A3BUWQ5C39GRQC  0.541667  0.625000  0.750000  0.500000  0.375000
# 29  A3CTXNQ2GXIQSP  0.875000  1.000000  0.958333  0.750000  0.666667
# 30  A3I8W5848LIHPC  0.750000  0.133333  0.333333  0.285714  0.555556
# 31  A3N8N0APBBUPT3  0.294118  0.333333  0.086957  0.428571  0.235294
# 32  A3NXT3OVGL7QNR  0.833333  0.916667  1.000000  0.791667  0.833333
# 33  A3UI9A8F9IDZTG  0.260870  0.363636  0.791667  0.625000  0.458333
# 34   A46IWW0R7ADY2  0.350000  0.565217  0.347826  0.318182  0.347826
# 35   A8UJNIY9R8S7W  0.565217  0.791667  0.800000  0.458333  0.541667
# 36   AFKB7F09OVKV7  0.625000  0.541667  0.695652  0.541667  0.416667
# 37   APGX2WZ59OWDN  1.000000  1.000000  1.000000  1.000000  0.958333
# 38   AQ5KOKZQSZU0B  0.750000  1.000000  1.000000  0.833333  0.791667
# 39   AXKTYKCT9NGHS  0.833333  1.000000  1.000000  0.791667  0.708333
# 40  A1LSSHKTJHSPWL  0.434783  0.434783  0.545455  0.500000  0.300000
# 41  A368U10UFMP2J6  0.400000  0.347826  0.391304  0.263158  0.285714
# 42  A3QTA32K0LP9AE  0.500000  0.347826  0.391304  0.263158  0.285714
# 43  A3EUTK958GXP5Z  0.173913  0.260870  0.363636  0.458333  0.250000
# 44  A11TPUPFP2S4MK  0.500000  0.833333  0.956522  0.458333  0.333333
# 45  A3PR7FCPPZ88JR  0.272727  0.454545  0.428571  0.222222  0.333333
# 46  A2VE2JM0RFYIOU  0.444444  0.500000  0.521739  0.375000  0.307692
# 47   AB3Z97M4JJLK5  0.200000  0.416667  0.166667  0.200000  0.400000
# 48  A2FGKKWP33DFWS  0.636364  0.750000  0.875000  0.521739  0.375000
# 49   AI0TZEH5DNODH  0.521739  0.421053  0.388889  0.600000  0.400000
# 50   AVBRJBJONL47I  0.391304  0.541667  0.666667  0.347826  0.250000
# 51  A1B5SSGMTAQ9B5  0.388889  0.294118  0.285714  0.100000  0.222222
#
#       Avg AC  Avg AB1_emo  Avg AB2_emo  Avg AB3_emo  Avg BC_emo  Avg XY_emo  \
# 0   0.583333     0.458333     0.521739     0.625000    0.521739    0.347826
# 1   0.791667     0.625000     0.916667     0.958333    0.708333    0.666667
# 2   0.416667     0.333333     0.363636     0.470588    0.222222    0.222222
# 3   0.583333     0.208333     0.625000     0.916667    0.375000    0.333333
# 4   0.500000     0.291667     0.833333     0.958333    0.541667    0.583333
# 5   0.208333     0.434783     0.347826     0.590909    0.153846    0.388889
# 6   0.291667     0.416667     0.500000     0.875000    0.291667    0.208333
# 7   0.333333     0.625000     0.875000     0.791667    0.208333    0.416667
# 8   0.791667     0.666667     0.916667     0.958333    0.541667    0.833333
# 9   0.875000     0.739130     0.833333     1.000000    0.791667    0.652174
# 10  0.541667     0.416667     0.750000     0.791667    0.434783    0.416667
# 11  0.833333     0.521739     0.826087     0.875000    0.666667    0.500000
# 12  0.750000     0.500000     0.791667     0.916667    0.708333    0.347826
# 13  0.958333     0.434783     0.916667     1.000000    0.916667    0.750000
# 14  0.333333     0.500000     0.791667     0.916667    0.375000    0.416667
# 15  0.250000     0.277778     0.304348     0.545455    1.000000    0.400000
# 16  0.625000     0.416667     0.625000     0.708333    0.625000    0.625000
# 17  0.958333     0.666667     0.875000     0.958333    0.916667    0.666667
# 18  0.625000     0.458333     0.708333     0.833333    0.500000    0.500000
# 19  0.291667     0.416667     0.666667     0.958333    0.333333    0.625000
# 20  0.375000     0.782609     0.916667     0.958333    0.750000    0.750000
# 21  0.208333     0.230769     0.521739     0.541667    0.444444    0.533333
# 22  0.625000     0.782609     0.782609     0.913043    0.869565    0.681818
# 23  0.833333     0.700000     0.916667     1.000000    0.900000    0.714286
# 24  0.958333     0.565217     0.875000     0.958333    0.666667    0.666667
# 25  0.625000     0.625000     0.625000     0.666667    0.541667    0.583333
# 26  0.208333     0.608696     0.727273     0.666667    0.588235    0.437500
# 27  0.333333     0.500000     0.583333     0.625000    0.400000    0.421053
# 28  0.500000     0.541667     0.708333     0.750000    0.416667    0.458333
# 29  0.916667     0.708333     0.958333     0.958333    0.750000    0.708333
# 30  0.083333     0.333333     0.230769     0.000000    0.500000    0.571429
# 31  0.375000     0.500000     0.411765     0.380952    0.250000    0.400000
# 32  0.916667     0.750000     0.875000     0.958333    0.833333    0.833333
# 33  0.458333     0.333333     0.571429     0.666667    0.291667    0.333333
# 34  0.375000     0.454545     0.458333     0.105263    0.318182    0.347826
# 35  0.500000     0.227273     0.500000     0.625000    0.583333    0.416667
# 36  0.375000     0.541667     0.500000     0.666667    0.583333    0.347826
# 37  1.000000     0.772727     0.916667     1.000000    0.916667    0.956522
# 38  0.916667     0.750000     0.916667     0.958333    0.750000    0.708333
# 39  0.875000     0.750000     0.833333     1.000000    0.750000    0.541667
# 40  0.541667     0.260870     0.541667     0.333333    0.272727    0.409091
# 41  0.250000     0.238095     0.285714     0.434783    0.473684    0.400000
# 42  0.125000     0.666667     0.000000     0.434783    0.473684    0.400000
# 43  0.250000     0.409091     0.375000     0.333333    0.100000    0.210526
# 44  0.583333     0.458333     0.608696     0.833333    0.409091    0.500000
# 45  0.250000     0.428571     0.285714     0.454545    0.500000    0.400000
# 46  0.291667     0.277778     0.571429     0.428571    0.333333    0.266667
# 47  0.083333     0.235294     0.615385     0.666667    0.333333    0.000000
# 48  0.458333     0.347826     0.391304     0.809524    0.565217    0.217391
# 49  0.291667     0.500000     0.266667     0.380952    0.222222    0.571429
# 50  0.666667     0.208333     0.521739     0.625000    0.458333    0.434783
# 51  0.416667     0.263158     0.285714     0.200000    0.400000    0.200000
#
#     Avg AC_emo
# 0     0.458333
# 1     0.708333
# 2     0.250000
# 3     0.458333
# 4     0.416667
# 5     0.250000
# 6     0.458333
# 7     0.291667
# 8     0.791667
# 9     0.875000
# 10    0.583333
# 11    0.708333
# 12    0.625000
# 13    0.791667
# 14    0.416667
# 15    0.250000
# 16    0.291667
# 17    0.875000
# 18    0.416667
# 19    0.500000
# 20    0.208333
# 21    0.416667
# 22    0.625000
# 23    0.750000
# 24    0.666667
# 25    0.458333
# 26    0.375000
# 27    0.291667
# 28    0.291667
# 29    0.750000
# 30    0.166667
# 31    0.291667
# 32    0.833333
# 33    0.541667
# 34    0.291667
# 35    0.458333
# 36    0.291667
# 37    1.000000
# 38    0.916667
# 39    0.666667
# 40    0.208333
# 41    0.250000
# 42    0.125000
# 43    0.375000
# 44    0.583333
# 45    0.333333
# 46    0.250000
# 47    0.208333
# 48    0.416667
# 49    0.250000
# 50    0.583333
# 51    0.333333

# %%
valence_df = pd.melt(val_df, id_vars=['participant'], value_vars=['Avg AB1', 'Avg AB2', 'Avg AB3', 'Avg BC', 'Avg XY','Avg AC', 'Avg AB1_emo', 'Avg AB2_emo', 'Avg AB3_emo', 'Avg BC_emo', 'Avg XY_emo', 'Avg AC_emo'], var_name='condition', value_name='Total_acc')
valence_df
# Out:
#         participant   condition  Total_acc
# 0    A106MX66IVHW6T     Avg AB1   0.666667
# 1    A12FTSX85NQ8N9     Avg AB1   0.650000
# 2    A140BPA53B1ZN2     Avg AB1   0.285714
# 3    A173A97OFDAX9F     Avg AB1   0.478261
# 4    A1DZMZTXWOM9MR     Avg AB1   0.416667
# ..              ...         ...        ...
# 619   AB3Z97M4JJLK5  Avg AC_emo   0.208333
# 620  A2FGKKWP33DFWS  Avg AC_emo   0.416667
# 621   AI0TZEH5DNODH  Avg AC_emo   0.250000
# 622   AVBRJBJONL47I  Avg AC_emo   0.583333
# 623  A1B5SSGMTAQ9B5  Avg AC_emo   0.333333
#
# [624 rows x 3 columns]

# %%
discard2 = []
for index, rows in valence_df.iterrows():
    if valence_df.condition[index] == 'Avg AB3_emo' and valence_df.Total_acc[index] <= 0.60:
        discard2.append(valence_df.participant[index])
print(discard2)
# Out:
# ['A140BPA53B1ZN2', 'A1Q56N80RJLQ7S', 'A2FECFFPL93VAI', 'A2SWQM5X54P1O5', 'A3I8W5848LIHPC', 'A3N8N0APBBUPT3', 'A46IWW0R7ADY2', 'A1LSSHKTJHSPWL', 'A368U10UFMP2J6', 'A3QTA32K0LP9AE', 'A3EUTK958GXP5Z', 'A3PR7FCPPZ88JR', 'A2VE2JM0RFYIOU', 'AI0TZEH5DNODH', 'A1B5SSGMTAQ9B5']

# %%
discard3 = []
for index, rows in valence_df.iterrows():
    if valence_df.condition[index] == 'Avg AC_emo' and valence_df.Total_acc[index] <= 0.33:
        discard3.append(valence_df.participant[index])
print(discard3)
# Out:
# ['A140BPA53B1ZN2', 'A1Q56N80RJLQ7S', 'A1SOFLJOEQB591', 'A2FECFFPL93VAI', 'A2I9R6P8PE5FDL', 'A2PSR3CMNR1R9X', 'A3BO3HMV0F7Q5H', 'A3BUWQ5C39GRQC', 'A3I8W5848LIHPC', 'A3N8N0APBBUPT3', 'A46IWW0R7ADY2', 'AFKB7F09OVKV7', 'A1LSSHKTJHSPWL', 'A368U10UFMP2J6', 'A3QTA32K0LP9AE', 'A2VE2JM0RFYIOU', 'AB3Z97M4JJLK5', 'AI0TZEH5DNODH']

# %%
valence_df.loc[valence_df['condition'] == 'Avg AB1', 'valence'] = 'c-neutral'
valence_df.loc[valence_df['condition'] == 'Avg AB2', 'valence'] = 'c-neutral'
valence_df.loc[valence_df['condition'] == 'Avg AB3', 'valence'] = 'c-neutral'
valence_df.loc[valence_df['condition'] == 'Avg BC', 'valence'] = 'c-neutral'
valence_df.loc[valence_df['condition'] == 'Avg XY', 'valence'] = 'c-neutral'
valence_df.loc[valence_df['condition'] == 'Avg AC', 'valence'] = 'c-neutral'


valence_df.loc[valence_df['condition'] == 'Avg AB1_emo', 'valence'] = 'fearful'
valence_df.loc[valence_df['condition'] == 'Avg AB2_emo', 'valence'] = 'fearful'
valence_df.loc[valence_df['condition'] == 'Avg AB3_emo', 'valence'] = 'fearful'
valence_df.loc[valence_df['condition'] == 'Avg BC_emo', 'valence'] = 'fearful'
valence_df.loc[valence_df['condition'] == 'Avg XY_emo', 'valence'] = 'fearful'
valence_df.loc[valence_df['condition'] == 'Avg AC_emo', 'valence'] = 'fearful'

# %%
valence_df
# Out:
#         participant   condition  Total_acc    valence
# 0    A106MX66IVHW6T     Avg AB1   0.666667  c-neutral
# 1    A12FTSX85NQ8N9     Avg AB1   0.650000  c-neutral
# 2    A140BPA53B1ZN2     Avg AB1   0.285714  c-neutral
# 3    A173A97OFDAX9F     Avg AB1   0.478261  c-neutral
# 4    A1DZMZTXWOM9MR     Avg AB1   0.416667  c-neutral
# ..              ...         ...        ...        ...
# 619   AB3Z97M4JJLK5  Avg AC_emo   0.208333    fearful
# 620  A2FGKKWP33DFWS  Avg AC_emo   0.416667    fearful
# 621   AI0TZEH5DNODH  Avg AC_emo   0.250000    fearful
# 622   AVBRJBJONL47I  Avg AC_emo   0.583333    fearful
# 623  A1B5SSGMTAQ9B5  Avg AC_emo   0.333333    fearful
#
# [624 rows x 4 columns]

# %%
comp_df = pd.melt(val_df, id_vars=['participant'], value_vars=['Avg AB3', 'Avg AB3_emo', 'Avg BC', 'Avg BC_emo', 'Avg XY', 'Avg XY_emo', 'Avg AC', 'Avg AC_emo'], var_name='condition', value_name='Total_acc')
comp_df
# Out:
#         participant   condition  Total_acc
# 0    A106MX66IVHW6T     Avg AB3   0.916667
# 1    A12FTSX85NQ8N9     Avg AB3   1.000000
# 2    A140BPA53B1ZN2     Avg AB3   0.181818
# 3    A173A97OFDAX9F     Avg AB3   0.791667
# 4    A1DZMZTXWOM9MR     Avg AB3   0.875000
# ..              ...         ...        ...
# 411   AB3Z97M4JJLK5  Avg AC_emo   0.208333
# 412  A2FGKKWP33DFWS  Avg AC_emo   0.416667
# 413   AI0TZEH5DNODH  Avg AC_emo   0.250000
# 414   AVBRJBJONL47I  Avg AC_emo   0.583333
# 415  A1B5SSGMTAQ9B5  Avg AC_emo   0.333333
#
# [416 rows x 3 columns]

# %%
comp_df.loc[comp_df['condition'] == 'Avg AB3', 'valence'] = 'c-neutral'
comp_df.loc[comp_df['condition'] == 'Avg BC', 'valence'] = 'c-neutral'
comp_df.loc[comp_df['condition'] == 'Avg XY', 'valence'] = 'c-neutral'
comp_df.loc[comp_df['condition'] == 'Avg AC', 'valence'] = 'c-neutral'


comp_df.loc[comp_df['condition'] == 'Avg AB3_emo', 'valence'] = 'fearful'
comp_df.loc[comp_df['condition'] == 'Avg BC_emo', 'valence'] = 'fearful'
comp_df.loc[comp_df['condition'] == 'Avg XY_emo', 'valence'] = 'fearful'
comp_df.loc[comp_df['condition'] == 'Avg AC_emo', 'valence'] = 'fearful'



comp_df.loc[comp_df['condition'] == 'Avg AB3', 'Test'] = 'AB3'
comp_df.loc[comp_df['condition'] == 'Avg BC', 'Test'] = 'BC'
comp_df.loc[comp_df['condition'] == 'Avg XY', 'Test'] = 'XY'
comp_df.loc[comp_df['condition'] == 'Avg AC', 'Test'] = 'AC'


comp_df.loc[comp_df['condition'] == 'Avg AB3_emo', 'Test'] = 'AB3'
comp_df.loc[comp_df['condition'] == 'Avg BC_emo', 'Test'] = 'BC'
comp_df.loc[comp_df['condition'] == 'Avg XY_emo', 'Test'] = 'XY'
comp_df.loc[comp_df['condition'] == 'Avg AC_emo', 'Test'] = 'AC'

# %%
comp_df
# Out:
#         participant   condition  Total_acc    valence Test
# 0    A106MX66IVHW6T     Avg AB3   0.916667  c-neutral  AB3
# 1    A12FTSX85NQ8N9     Avg AB3   1.000000  c-neutral  AB3
# 2    A140BPA53B1ZN2     Avg AB3   0.181818  c-neutral  AB3
# 3    A173A97OFDAX9F     Avg AB3   0.791667  c-neutral  AB3
# 4    A1DZMZTXWOM9MR     Avg AB3   0.875000  c-neutral  AB3
# ..              ...         ...        ...        ...  ...
# 411   AB3Z97M4JJLK5  Avg AC_emo   0.208333    fearful   AC
# 412  A2FGKKWP33DFWS  Avg AC_emo   0.416667    fearful   AC
# 413   AI0TZEH5DNODH  Avg AC_emo   0.250000    fearful   AC
# 414   AVBRJBJONL47I  Avg AC_emo   0.583333    fearful   AC
# 415  A1B5SSGMTAQ9B5  Avg AC_emo   0.333333    fearful   AC
#
# [416 rows x 5 columns]

# %%
sns.set(font_scale = 1.5)
g = sns.catplot(x="Test", y="Total_acc", hue="valence", data=comp_df,
 height=6, kind="bar", palette="crest", capsize=.1)
g = sns.swarmplot(x="Test", y="Total_acc", hue="valence", data=comp_df, palette="rocket", dodge=True)
g.legend_.remove()
#g.figure.savefig('mean_bias_context_age_source_corr_bars.pdf')
plt.ylim(-0.1, 1.05)
plt.ylabel("Proprtion correct")
plt.xlabel('')
plt.show()
# Out:
# C:\Users\ayesh\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ayesh\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
preAC_comp_df = pd.melt(val_df, id_vars=['participant'], value_vars=['Avg AB1', 'Avg AB1_emo', 'Avg AB2', 'Avg AB2_emo','Avg AB3', 'Avg AB3_emo', 'Avg BC', 'Avg BC_emo', 'Avg XY', 'Avg XY_emo'], var_name='condition', value_name='Total_acc')
preAC_comp_df
# Out:
#         participant   condition  Total_acc
# 0    A106MX66IVHW6T     Avg AB1   0.666667
# 1    A12FTSX85NQ8N9     Avg AB1   0.650000
# 2    A140BPA53B1ZN2     Avg AB1   0.285714
# 3    A173A97OFDAX9F     Avg AB1   0.478261
# 4    A1DZMZTXWOM9MR     Avg AB1   0.416667
# ..              ...         ...        ...
# 515   AB3Z97M4JJLK5  Avg XY_emo   0.000000
# 516  A2FGKKWP33DFWS  Avg XY_emo   0.217391
# 517   AI0TZEH5DNODH  Avg XY_emo   0.571429
# 518   AVBRJBJONL47I  Avg XY_emo   0.434783
# 519  A1B5SSGMTAQ9B5  Avg XY_emo   0.200000
#
# [520 rows x 3 columns]

# %%
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB3', 'valence'] = 'c-neutral'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg BC', 'valence'] = 'c-neutral'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB2', 'valence'] = 'c-neutral'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB1', 'valence'] = 'c-neutral'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg XY', 'valence'] = 'c-neutral'


preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB3_emo', 'valence'] = 'fearful'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg BC_emo', 'valence'] = 'fearful'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB2_emo', 'valence'] = 'fearful'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB1_emo', 'valence'] = 'fearful'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg XY_emo', 'valence'] = 'fearful'


preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB3', 'Test'] = 'AB3'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg BC', 'Test'] = 'BC'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB2', 'Test'] = 'AB2'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB1', 'Test'] = 'AB1'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg XY', 'Test'] = 'XY'

preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB3_emo', 'Test'] = 'AB3'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg BC_emo', 'Test'] = 'BC'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB2_emo', 'Test'] = 'AB2'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg AB1_emo', 'Test'] = 'AB1'
preAC_comp_df.loc[preAC_comp_df['condition'] == 'Avg XY_emo', 'Test'] = 'XY'

# %%
preAC_comp_df
# Out:
#         participant   condition  Total_acc    valence Test
# 0    A106MX66IVHW6T     Avg AB1   0.666667  c-neutral  AB1
# 1    A12FTSX85NQ8N9     Avg AB1   0.650000  c-neutral  AB1
# 2    A140BPA53B1ZN2     Avg AB1   0.285714  c-neutral  AB1
# 3    A173A97OFDAX9F     Avg AB1   0.478261  c-neutral  AB1
# 4    A1DZMZTXWOM9MR     Avg AB1   0.416667  c-neutral  AB1
# ..              ...         ...        ...        ...  ...
# 515   AB3Z97M4JJLK5  Avg XY_emo   0.000000    fearful   XY
# 516  A2FGKKWP33DFWS  Avg XY_emo   0.217391    fearful   XY
# 517   AI0TZEH5DNODH  Avg XY_emo   0.571429    fearful   XY
# 518   AVBRJBJONL47I  Avg XY_emo   0.434783    fearful   XY
# 519  A1B5SSGMTAQ9B5  Avg XY_emo   0.200000    fearful   XY
#
# [520 rows x 5 columns]

# %%
sns.set(font_scale = 1.5)
g = sns.catplot(x="Test", y="Total_acc", hue="valence", data=preAC_comp_df,
 height=6, kind="bar", palette="crest", capsize=.1)
g = sns.swarmplot(x="Test", y="Total_acc", hue="valence", data=preAC_comp_df, palette="rocket", dodge=True)
g.legend_.remove()
#g.figure.savefig('mean_bias_context_age_source_corr_bars.pdf')
plt.ylim(-0.1, 1.05)
plt.ylabel("Proprtion correct")
plt.xlabel('')
plt.show()
# Out:
# C:\Users\ayesh\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ayesh\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
AB_comp_df = pd.melt(val_df, id_vars=['participant'], value_vars=['Avg AB3', 'Avg AB3_emo', 'Avg BC', 'Avg BC_emo', 'Avg XY', 'Avg XY_emo'], var_name='condition', value_name='Total_acc')
AB_comp_df
# Out:
#         participant   condition  Total_acc
# 0    A106MX66IVHW6T     Avg AB3   0.916667
# 1    A12FTSX85NQ8N9     Avg AB3   1.000000
# 2    A173A97OFDAX9F     Avg AB3   0.791667
# 3    A1DZMZTXWOM9MR     Avg AB3   0.875000
# 4    A1SISJL5ST2PWH     Avg AB3   0.625000
# ..              ...         ...        ...
# 193   APGX2WZ59OWDN  Avg XY_emo   0.956522
# 194   AQ5KOKZQSZU0B  Avg XY_emo   0.708333
# 195   AXKTYKCT9NGHS  Avg XY_emo   0.541667
# 196  A11TPUPFP2S4MK  Avg XY_emo   0.500000
# 197  A2FGKKWP33DFWS  Avg XY_emo   0.217391
#
# [198 rows x 3 columns]

# %%
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg AB3', 'valence'] = 'AB-control'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg BC', 'valence'] = 'BC-control'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg BC', 'valence'] = 'XY-control'


AB_comp_df.loc[AB_comp_df['condition'] == 'Avg AB3_emo', 'valence'] = 'AB-fearful'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg BC_emo', 'valence'] = 'BC-fearful'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg ABfinal_emo', 'valence'] = 'AB-fearful'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg BCfinal_emo', 'valence'] = 'BC-fearful'


AB_comp_df.loc[AB_comp_df['condition'] == 'Avg AB3', 'Test'] = 'pre'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg BC', 'Test'] = 'pre'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg ABfinal', 'Test'] = 'post'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg BCfinal', 'Test'] = 'post'

AB_comp_df.loc[AB_comp_df['condition'] == 'Avg AB3_emo', 'Test'] = 'pre'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg BC_emo', 'Test'] = 'pre'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg ABfinal_emo', 'Test'] = 'post'
AB_comp_df.loc[AB_comp_df['condition'] == 'Avg BCfinal_emo', 'Test'] = 'post'

# %%
AB_comp_df
# Out:
#         participant   condition  Total_acc     valence Test
# 0    A106MX66IVHW6T     Avg AB3   0.916667  AB-control  pre
# 1    A12FTSX85NQ8N9     Avg AB3   1.000000  AB-control  pre
# 2    A173A97OFDAX9F     Avg AB3   0.791667  AB-control  pre
# 3    A1DZMZTXWOM9MR     Avg AB3   0.875000  AB-control  pre
# 4    A1SISJL5ST2PWH     Avg AB3   0.625000  AB-control  pre
# ..              ...         ...        ...         ...  ...
# 193   APGX2WZ59OWDN  Avg XY_emo   0.956522         NaN  NaN
# 194   AQ5KOKZQSZU0B  Avg XY_emo   0.708333         NaN  NaN
# 195   AXKTYKCT9NGHS  Avg XY_emo   0.541667         NaN  NaN
# 196  A11TPUPFP2S4MK  Avg XY_emo   0.500000         NaN  NaN
# 197  A2FGKKWP33DFWS  Avg XY_emo   0.217391         NaN  NaN
#
# [198 rows x 5 columns]

# %%
#check for interference
#here if there is a difference between pre and post AC test, it will be indicated by different colors. 
#If pre AC performance is better than the post AC performance, line is blue, otherwise red!
#note that if there is no difference, i.e, if pre-post = 0, the line is still red!
red = '#c04e01'
blue = '#0165fc'
fig, ax = plt.subplots(figsize=(8, 8))

# Set up list to track sites
valences = []

i = 1.0
for valence, subdf in AB_comp_df.groupby('valence'):
    valences.append(valence)
    # Get the values for healthy and disease patients
    h = subdf.query('Test == "pre"')['Total_acc'].values
    d = subdf.query('Test == "post"')['Total_acc'].values
    # Set up the x-axis values
    x1 = i - 0.2
    x2 = i + 0.2
 # Set up line color
    line_colors = (h - d) > 0
    line_colors = [blue if j else red for j in line_colors]
    # Also set up alpha values to make the lines slightly transparent
    alphas = [0.4]*len(line_colors)
    # Plot the lines connecting the dots
    for hi, di, ci, ai in zip(h, d, line_colors, alphas):
        ax.plot([x1, x2], [hi, di], c=ci, alpha=ai)
 # Plot the points
 # Note: s=25 increase the default point size, lw=0.5 decreases the default point line width
    ax.scatter(len(h)*[x1-0.01], h, c=blue,
    s=25, lw=0.5, label='Pre-AC')
    ax.scatter(len(d)*[x2+0.01], d, c=red,
    s=25, lw=0.5, label='Post-AC')
 # Update x-axis
    i += 1
# Fix the axes and labels
ax.set_xticks([1, 2, 3, 4])
_ = ax.set_xticklabels(valences, fontsize='large')
# Add legend and fix it to show only the first two elements
handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles[0:2], labels[0:2],
    fontsize='large',
    loc='upper center',
    bbox_to_anchor=(0.5, 1.25),
    ncol=2,
    scatterpoints=1)
lgd.legendHandles[0]._sizes = [80]
lgd.legendHandles[1]._sizes = [80]
ax.set_xlabel('Test phase')
ax.set_ylabel('Response Accuracy')
    #fig.savefig('mean_bias_context_age_source_corr_points.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-7aa10ed0e82d> in <module>
#      20     x2 = i + 0.2
#      21  # Set up line color
# ---> 22     line_colors = (h - d) > 0
#      23     line_colors = [blue if j else red for j in line_colors]
#      24     # Also set up alpha values to make the lines slightly transparent
#
# ValueError: operands could not be broadcast together with shapes (33,) (0,)

# %%
h-d
# Out:
# array([ 0.08333333,  0.01992754,  0.125     , -0.05681818,  0.        ,
#         0.        , -0.18452381, -0.08333333,  0.07608696, -0.08333333,
#         0.19565217,  0.16666667, -0.08333333, -0.04166667,  0.08333333,
#        -0.125     , -0.11594203,  0.        , -0.3134058 ,  0.19762846,
#        -0.08333333,  0.01086957, -0.04166667, -0.16666667, -0.19384058,
#        -0.20833333,  0.04166667,  0.08333333,  0.125     ,  0.04166667])

# %%
line_colors
# Out:
# ['#0165fc',
#  '#0165fc',
#  '#0165fc',
#  '#c04e01',
#  '#c04e01',
#  '#c04e01',
#  '#c04e01',
#  '#c04e01',
#  '#0165fc',
#  '#c04e01',
#  '#0165fc',
#  '#0165fc',
#  '#c04e01',
#  '#c04e01',
#  '#0165fc',
#  '#c04e01',
#  '#c04e01',
#  '#c04e01',
#  '#c04e01',
#  '#0165fc',
#  '#c04e01',
#  '#0165fc',
#  '#c04e01',
#  '#c04e01',
#  '#c04e01',
#  '#c04e01',
#  '#0165fc',
#  '#0165fc',
#  '#0165fc',
#  '#0165fc']
